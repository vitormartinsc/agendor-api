# %%
import gspread
import pandas as pd
import requests
import time
from thefuzz import process  # Biblioteca para fuzzy matching
from oauth2client.service_account import ServiceAccountCredentials
from unidecode import unidecode

scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]

# Autenticação com credenciais do JSON (substitua pelo seu arquivo JSON)
creds = ServiceAccountCredentials.from_json_keyfile_name("../credenciais/credenciais.json", scope)
client = gspread.authorize(creds)
spreadsheet = client.open('TPV Final')

# %%
def get_tpv_database(bank):
    sheet = spreadsheet.worksheet(f"Base ({bank})")  # Substitua pelo nome da aba da planilha
    data = sheet.get_all_values()
    if bank == 'inter':
        i = 3
    elif bank == 'own': 
        i = 2
    headers = data[i]  # A terceira linha (índice 2) contém os cabeçalhos
    db = pd.DataFrame(data[i+1:], columns=headers)
    #colunas_desejadas = ["Nome Completo"] + [col for col in db.columns if "/" in col]
    return db

# %%
get_tpv_database('own')
# Out:
#       Nº CNPJ Estabelecimento                           Nome Completo  \
# 0      1            667267352                 MARAISA DA SILVA CABRAL
# 1      2            708549632                     JOAO GOMES DA SILVA
# 2      3            724945300                 CLAUDIONOR CUNHA SANTOS
# 3      4            870409301               CLEONILDE SANTOS DE MATOS
# 4      5            902091417  JUAREZA PATRICIA SOUZA FERNANDES ALVES
# ..   ...                  ...                                     ...
# 189  190          85983357115  FABIO EUSTAQUIO GUALBERTO SOARES SILVA
# 190  191          90079826806                   NICOLAS COLIN CORREIA
# 191  192          95780254087                        FABIANA DA SILVA
# 192  193          98012924749                   ROGERIO LUIZ DA SILVA
# 193  194          98952099249                BENEDITO FARIAS DA SILVA
#
#             Nome Fantasia Dias Transacionados       ACM 17/07/2024 18/07/2024  \
# 0    MARAISA DA SILVA CAB                   8    217,50
# 1     JOAO GOMES DA SILVA                  26  1.420,37
# 2        KLAU STUDIO HAIR                   1      5,00
# 3     CLEONILDE SANTOS DE                   4    307,31
# 4     LANCHONETE CANTINHO                   3     24,08
# ..                    ...                 ...       ...        ...        ...
# 189  FABIO EUSTAQUIO GUAL                   9    399,00
# 190  NICOLAS COLIN CORREI                   3      5,90
# 191      FABIANA DA SILVA                   2      3,00
# 192  ROGERIO LUIZ DA SILV                   4    145,10
# 193  BENEDITO FARIAS DA S                  44  1.369,52
#
#     19/07/2024 22/07/2024  ... 14/03/2025 15/03/2025 16/03/2025 17/03/2025  \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
# ..         ...        ...  ...        ...        ...        ...        ...
# 189                        ...
# 190                        ...
# 191                        ...
# 192                        ...
# 193                        ...
#
#     18/03/2025 19/03/2025 20/03/2025 21/03/2025 22/03/2025 23/03/2025
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...        ...
# 189
# 190
# 191
# 192
# 193
#
# [194 rows x 252 columns]

# %% [markdown]
# # UPDATING DATABASE

# %%
bank = 'own'
sheet = spreadsheet.worksheet(f"Base ({bank})")  # Substitua pelo nome da aba da planilha
data = sheet.get_all_values()
if bank == 'inter':
    i = 3
elif bank == 'own': 
    i = 2
headers = data[i]  # A terceira linha (índice 2) contém os cabeçalhos
db = pd.DataFrame(data[i+1:], columns=headers)

# %%
df = pd.read_csv('relatorio_diario_own.csv')

df["VGT"] = (
    df["VGT"]
    .str.replace("R$", "")   # Remove "R$"
    .str.replace(".", "")    # Remove pontos dos milhares
    .str.replace(",", ".")   # Substitui vírgula decimal por ponto
).astype(float)

df['CNPJ Estabelecimento'] = df['CNPJ Estabelecimento'].astype(str)

data_metrica = df['Data Métrica'][0]
df_grouped = df.groupby("CNPJ Estabelecimento", as_index=False)["VGT"].sum()

# %%
df_grouped = df_grouped.rename(columns={"VGT": data_metrica})

# %%
df_grouped
# Out:
#   CNPJ Estabelecimento  10/03/2025
# 0       49820887000153        18.0
# 1       53758067000156         7.0
# 2       55507385000170         2.5
# 3           6305354421       700.0
# 4           6702705476        20.5
# 5           7733325706        27.5
# 6            968362532       852.0
# 7          98012924749       139.1

# %%
date_col = df_grouped.columns[1]
# Atualizar os valores da coluna correspondente à data
for index, row in df_grouped.iterrows():
    cnpj = row.iloc[0]
    value = row.iloc[1]

    # Verifica se o CNPJ existe no DataFrame principal antes de atualizar
    mask = db["CNPJ Estabelecimento"] == cnpj
    if mask.any():
        db.loc[mask, date_col] = value  # Atualiza os valores correspondentes

# %%
db[['Nome Completo', date_col]][date_col].value_counts()
# Out:
# 10/03/2025
#          186
# 852.0      1
# 700.0      1
# 20.5       1
# 27.5       1
# 18.0       1
# 7.0        1
# 2.5        1
# 139.1      1
# Name: count, dtype: int64

# %%
# Converter DataFrame para lista (sem cabeçalhos)
data_to_update = db.values.tolist()

# %%
sheet.update(range_name="A4", values=data_to_update)
# Out:
# {'spreadsheetId': '1By0bJacAhBjZaELBw6vAFqaNd4B3gJt5JJKiLsswlm8',
#  'updatedRange': "'Cópia de Base (own)'!A4:IR197",
#  'updatedRows': 194,
#  'updatedColumns': 252,
#  'updatedCells': 48888}

# %% [markdown]
# # UPDATING CRM (AGENDOR)

# %% [markdown]
# ##### Getting full database

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import pandas as pd

# %%
gauth = GoogleAuth()


#gauth.settings['client_config_file'] = '../credenciais/credenciais_drive.json'

# Tenta carregar as credenciais salvas ou autentica via servidor web local
gauth.LocalWebserverAuth()
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=669886130571-7i6v3tb4g14m9jui26rfjeod3mlf208p.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
import pandas as pd
import requests
from io import BytesIO

# 📌 URL para exportar a planilha como Excel (.xlsx)
xlsx_url = "https://docs.google.com/spreadsheets/d/1GpB1ed23HZhNKQciU3DSKC05ZowEirr0/export?format=xlsx&gid=520903099"

# 🔽 Baixar o arquivo
response = requests.get(xlsx_url)
response.raise_for_status()  # Garante que o download foi bem-sucedido

# 📖 Ler o arquivo Excel diretamente da memória
df_inter = pd.read_excel(BytesIO(response.content), engine="openpyxl", sheet_name = 'Base (inter)', header=3)

# 📌 URL para exportar a planilha como Excel (.xlsx)
xlsx_url = "https://docs.google.com/spreadsheets/d/1GpB1ed23HZhNKQciU3DSKC05ZowEirr0/edit?usp=sharing&ouid=105417421490865173338&rtpof=true&sd=true"

# 🔽 Baixar o arquivo
response = requests.get(xlsx_url)
response.raise_for_status()  # Garante que o download foi bem-sucedido

# 📖 Ler o arquivo Excel diretamente da memória
df_own = pd.read_excel(BytesIO(response.content), engine="openpyxl", sheet_name = 'Base (own)', header=2)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[61], line 23
#      20 response.raise_for_status()  # Garante que o download foi bem-sucedido
#      22 # 📖 Ler o arquivo Excel diretamente da memória
# ---> 23 df_own = pd.read_excel(BytesIO(response.content), engine="openpyxl", sheet_name = 'Base (own)', header=2)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:573, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     571 self.handles.handle.seek(0)
#     572 try:
# --> 573     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     574 except Exception:
#     575     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:572, in OpenpyxlReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#     568 from openpyxl import load_workbook
#     570 default_kwargs = {"read_only": True, "data_only": True, "keep_links": False}
# --> 572 return load_workbook(
#     573     filepath_or_buffer,
#     574     **(default_kwargs | engine_kwargs),
#     575 )
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)
#     344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1349, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1347 try:
#    1348     if mode == 'r':
# -> 1349         self._RealGetContents()
#    1350     elif mode in ('w', 'x'):
#    1351         # set the modified flag so central directory gets written
#    1352         # even if no files are added to the archive
#    1353         self._didModify = True
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1416, in ZipFile._RealGetContents(self)
#    1414     raise BadZipFile("File is not a zip file")
#    1415 if not endrec:
# -> 1416     raise BadZipFile("File is not a zip file")
#    1417 if self.debug > 1:
#    1418     print(endrec)
#
# BadZipFile: File is not a zip file

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import pandas as pd



# 📥 ID da planilha no Google Drive
file_id = "1GpB1ed23HZhNKQciU3DSKC05ZowEirr0"
output_file = "planilha.xlsx"
drive = GoogleDrive(gauth)

# 📌 Baixar o arquivo
file = drive.CreateFile({'id': file_id})
file.GetContentFile(output_file)

# 📖 Ler a planilha no Pandas
df = pd.read_excel(output_file, sheet_name="Base (inter)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\base.py:59, in _convert(expected_type, value)
#      58 try:
# ---> 59     value = expected_type(value)
#      60 except:
#
# ValueError: invalid literal for int() with base 10: ''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 17
#      14 file.GetContentFile(output_file)
#      16 # 📖 Ler a planilha no Pandas
# ---> 17 df = pd.read_excel(output_file, sheet_name="Base (inter)")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:573, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     571 self.handles.handle.seek(0)
#     572 try:
# --> 573     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     574 except Exception:
#     575     self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:572, in OpenpyxlReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#     568 from openpyxl import load_workbook
#     570 default_kwargs = {"read_only": True, "data_only": True, "keep_links": False}
# --> 572 return load_workbook(
#     573     filepath_or_buffer,
#     574     **(default_kwargs | engine_kwargs),
#     575 )
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:293, in ExcelReader.read(self)
#     291 self.read_strings()
#     292 action = "read workbook"
# --> 293 self.read_workbook()
#     294 action = "read properties"
#     295 self.read_properties()
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\excel.py:153, in ExcelReader.read_workbook(self)
#     151 wb_part = _find_workbook_part(self.package)
#     152 self.parser = WorkbookParser(self.archive, wb_part.PartName[1:], keep_links=self.keep_links)
# --> 153 self.parser.parse()
#     154 wb = self.parser.wb
#     155 wb._sheets = []
#
# File ~\anaconda3\Lib\site-packages\openpyxl\reader\workbook.py:46, in WorkbookParser.parse(self)
#      44 src = self.archive.read(self.workbook_part_name)
#      45 node = fromstring(src)
# ---> 46 package = WorkbookPackage.from_tree(node)
#      47 if package.properties.date1904:
#      48     self.wb.epoch = CALENDAR_MAC_1904
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\serialisable.py:83, in Serialisable.from_tree(cls, node)
#      79     continue
#      81 if hasattr(desc, 'from_tree'):
#      82     #descriptor manages conversion
# ---> 83     obj = desc.from_tree(el)
#      84 else:
#      85     if hasattr(desc.expected_type, "from_tree"):
#      86         #complex type
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\sequence.py:94, in NestedSequence.from_tree(self, node)
#      93 def from_tree(self, node):
# ---> 94     return [self.expected_type.from_tree(el) for el in node]
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\serialisable.py:103, in Serialisable.from_tree(cls, node)
#     100     else:
#     101         attrib[tag] = obj
# --> 103 return cls(**attrib)
#
# File ~\anaconda3\Lib\site-packages\openpyxl\workbook\views.py:62, in BookView.__init__(self, visibility, minimized, showHorizontalScroll, showVerticalScroll, showSheetTabs, xWindow, yWindow, windowWidth, windowHeight, tabRatio, firstSheet, activeTab, autoFilterDateGrouping, extLst)
#      60 self.showVerticalScroll = showVerticalScroll
#      61 self.showSheetTabs = showSheetTabs
# ---> 62 self.xWindow = xWindow
#      63 self.yWindow = yWindow
#      64 self.windowWidth = windowWidth
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\base.py:71, in Convertible.__set__(self, instance, value)
#      68 def __set__(self, instance, value):
#      69     if ((self.allow_none and value is not None)
#      70         or not self.allow_none):
# ---> 71         value = _convert(self.expected_type, value)
#      72     super().__set__(instance, value)
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\base.py:61, in _convert(expected_type, value)
#      59         value = expected_type(value)
#      60     except:
# ---> 61         raise TypeError('expected ' + str(expected_type))
#      62 return value
#
# TypeError: expected <class 'int'>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import pandas as pd

# 📌 Autenticar com o Google Drive
gauth = GoogleAuth()

# Carrega as credenciais do arquivo credentials.json
gauth.LoadCredentialsFile("../credenciais/credenciais.json")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 9
#       6 gauth = GoogleAuth()
#       8 # Carrega as credenciais do arquivo credentials.json
# ----> 9 gauth.LoadCredentialsFile("../credenciais/credenciais.json")
#
# File ~\anaconda3\Lib\site-packages\pydrive\auth.py:308, in GoogleAuth.LoadCredentialsFile(self, credentials_file)
#     306 try:
#     307   storage = Storage(credentials_file)
# --> 308   self.credentials = storage.get()
#     309 except IOError:
#     310   raise InvalidCredentialsError('Credentials file cannot be symbolic link')
#
# File ~\anaconda3\Lib\site-packages\oauth2client\client.py:407, in Storage.get(self)
#     405 self.acquire_lock()
#     406 try:
# --> 407     return self.locked_get()
#     408 finally:
#     409     self.release_lock()
#
# File ~\anaconda3\Lib\site-packages\oauth2client\file.py:54, in Storage.locked_get(self)
#      51     return credentials
#      53 try:
# ---> 54     credentials = client.Credentials.new_from_json(content)
#      55     credentials.set_store(self)
#      56 except ValueError:
#
# File ~\anaconda3\Lib\site-packages\oauth2client\client.py:302, in Credentials.new_from_json(cls, json_data)
#     299 data = json.loads(json_data_as_unicode)
#     300 # Find and call the right classmethod from_json() to restore
#     301 # the object.
# --> 302 module_name = data['_module']
#     303 try:
#     304     module_obj = __import__(module_name)
#
# KeyError: '_module'

# %%
df_final = (
    pd.concat([data_own, data_inter], ignore_index=True)
    .fillna(0)
    .melt(id_vars=["Nome Completo"], var_name="date", value_name="value")  # Equivalente ao gather()
    .assign(
        value=lambda d: d["value"].fillna("0")  # Substitui NA por '0'
        .astype(str)
        .str.replace(".", "", regex=False)
        .str.replace(",", ".", regex=False)
        .replace("", "0")
        .astype(float),  # Converte valores para float
        date=lambda d: pd.to_datetime(d["date"], format="%d/%m/%Y"),  # Converte data
    )
    .rename(columns={"Nome Completo": "name"})  # Renomeia a coluna
    .sort_values(by=["name", "date"])  # Ordena os dados
    .reset_index(drop=True)
    .assign(
        tpv_60_d=lambda d: d.groupby("name")["value"].transform(lambda x: x.rolling(window=60, min_periods=1).sum()),
        tpv_30_d=lambda d: d.groupby("name")["value"].transform(lambda x: x.rolling(window=30, min_periods=1).sum()),
        tpv_historico=lambda d: d.groupby("name")["value"].cumsum(),
    )
    .loc[lambda d: d['date'] == pd.Timestamp.today().normalize()]
    .drop(columns=['date', 'value'])
)

# %%
API_KEY = "881078-ec5446d8-7fbd-4fac-806d-8a4d81eece36"
URL = "https://api.agendor.com.br/v3/deals"


headers = {
    "Authorization": f"Token {API_KEY}",
    "Content-Type": "application/json"
}

# %%
# Função para realizar o scraping
def fetch_data():
    next_url = URL
    params = {"per_page": 100}
    all_json_deals_data = []
    wait_time = 10  # Tempo inicial de espera em segundos

    while next_url:
        try:
            response = requests.get(next_url, headers=headers, params=params)

            if response.status_code == 200:
                json_deal_data = response.json().get('data', [])
                all_json_deals_data.extend(json_deal_data)
                links = response.json().get('links', {})
                next_url = links.get('next', False)
                wait_time = 10  # Reseta o tempo de espera se der certo

            elif response.status_code == 429:
                print(f"Erro 429: Muitas requisições. Aguardando {wait_time} segundos antes de tentar novamente...")
                time.sleep(wait_time)
                wait_time *= 2  # Dobra o tempo de espera a cada falha

            else:
                print(f"Erro {response.status_code}: {response.text}")
                break  # Sai do loop se for outro erro

        except requests.exceptions.JSONDecodeError:
            print("Erro ao decodificar JSON. Resposta vazia ou malformada.")
            break
        except requests.exceptions.RequestException as e:
            print(f"Erro na requisição: {e}")
            break

    return all_json_deals_data

# %%
deals = fetch_data()

# %%
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]

# Autenticação com credenciais do JSON (substitua pelo seu arquivo JSON)
creds = ServiceAccountCredentials.from_json_keyfile_name("../credenciais/credenciais.json", scope)
client = gspread.authorize(creds)
spreadsheet = client.open('TPV Final')

# %%
sheet = spreadsheet.worksheet("02. Own")  # Substitua pelo nome da aba da planilha

data = sheet.get_all_values()

# Definir os cabeçalhos como a terceira linha
headers = data[4]  # A terceira linha (índice 2) contém os cabeçalhos

# Criar um DataFrame a partir da quarta linha em diante
db_names = pd.DataFrame(data[5:], columns=headers)[['PESSOA RELACIONADA', 'CADASTRO OWN']]

# %%
mapping = dict(zip(db_names["CADASTRO OWN"], db_names["PESSOA RELACIONADA"]))

# %%
df_final["name"] = df_final["name"].map(lambda x: mapping.get(x, x)).apply(normalize_name)
df_final['name'] = df_final['name'].apply(lambda x: 'fernanda sousa vieira' if x == 'fernada sousa vieira' else x)

# %%
all_crm_names = {}
for deal in deals:
    if deal['person'] and deal['dealStatus']['name'] == 'Em andamento':
        crm_name = normalize_name(deal['person']['name'])
        if crm_name not in all_crm_names:
            all_crm_names[crm_name] = deal['id']

# %%
def normalize_name(name):
    return unidecode(name).lower().strip()

# %%
matches = {}

# Loop para encontrar o nome mais próximo no CRM
for name in df_final["name"]:
    name_parts = name.split()
    first_name = name_parts[0]  # Pegamos o primeiro nome
    score_for_name = {}

    for crm_name in all_crm_names.keys():
        crm_name_parts = crm_name.split()
        if crm_name_parts:
            first_crm_name = crm_name_parts[0]

            # 🔍 Se o primeiro nome for igual, analisamos os sobrenomes
            if first_name == first_crm_name:
                score = sum(1 for surname in name_parts[1:] if surname in crm_name_parts)
                score_for_name[crm_name] = score  # Armazena o score

    # Se encontramos pelo menos um nome com o primeiro nome igual
    if score_for_name:
        best_match = max(score_for_name, key=score_for_name.get)  # Pega o nome com maior score
        matches[name] = all_crm_names[best_match]  # Mapeia para o CRM
    else:
        print(name)
        matches[name] = None  # Nenhuma correspondência encontrada
# Out:
# alice alves rosostolato
# maicon carvalho de oliveira
# elisangela aparecida silva de souza
# misael rodrigues araujo
# erick jesus gotardo
# elcio de araujo valente
# franclin jonas vieira da silva
# jonas freitas da hora
# marivaldo da silva cavalcante

# %%
df_final["deal_id"] = df_final["name"].apply(matches.get)

# %%
df_final.dropna(inplace=True)

# %%
BASE_URL = "https://api.agendor.com.br/v3"

headers = {
    "Authorization": f"Token {API_KEY}",
    "Content-Type": "application/json"
}

for i, row in df_final.iterrows():
    deal_id = str(int(row['deal_id']))
    tpv_historico = str(row['tpv_historico'])
    tpv_30_d = str(row['tpv_30_d'])
    tpv_60_d = str(row['tpv_60_d'])
    url = f"{BASE_URL}/deals/{deal_id}"
    payload = {"customFields": {'tpv_historico': tpv_historico, 'tpv_mes_anterior': tpv_30_d, 'tpv_m-2': tpv_60_d}}  

    wait_time = 10  # Tempo de espera inicial
    
    while True:
        response = requests.put(url, headers=headers, json=payload)

        if response.status_code == 200:
            wait_time = 10  # Reseta o tempo de espera se der certo
            print(f"Sucesso para {i}")  # Corrigido o uso de f-string
            break
            
        elif response.status_code == 429:
            print(f"Erro 429: Muitas requisições. Aguardando {wait_time} segundos antes de tentar novamente...")
            time.sleep(wait_time)
            wait_time *= 2  # Dobra o tempo de espera a cada falha
        else:
            print(f"Erro inesperado para {i}: {response.status_code}")
            break  # Você pode optar por parar ou continuar com outro comportamento

    print(f"Processado {i} de {len(df_final)}")
# Out:
# Sucesso para 0
# Processado 0 de 225
# Sucesso para 1
# Processado 1 de 225
# Sucesso para 2
# Processado 2 de 225
# Sucesso para 3
# Processado 3 de 225
# Sucesso para 4
# Processado 4 de 225
# Sucesso para 5
# Processado 5 de 225
# Sucesso para 6
# Processado 6 de 225
# Sucesso para 7
# Processado 7 de 225
# Sucesso para 8
# Processado 8 de 225
# Sucesso para 9
# Processado 9 de 225
# Sucesso para 10
# Processado 10 de 225
# Sucesso para 11
# Processado 11 de 225
# Sucesso para 12
# Processado 12 de 225
# Sucesso para 13
# Processado 13 de 225
# Sucesso para 15
# Processado 15 de 225
# Sucesso para 17
# Processado 17 de 225
# Sucesso para 18
# Processado 18 de 225
# Sucesso para 19
# Processado 19 de 225
# Sucesso para 20
# Processado 20 de 225
# Sucesso para 21
# Processado 21 de 225
# Sucesso para 22
# Processado 22 de 225
# Sucesso para 23
# Processado 23 de 225
# Sucesso para 24
# Processado 24 de 225
# Sucesso para 25
# Processado 25 de 225
# Sucesso para 26
# Processado 26 de 225
# Sucesso para 27
# Processado 27 de 225
# Sucesso para 28
# Processado 28 de 225
# Sucesso para 29
# Processado 29 de 225
# Sucesso para 30
# Processado 30 de 225
# Sucesso para 31
# Processado 31 de 225
# Sucesso para 32
# Processado 32 de 225
# Sucesso para 33
# Processado 33 de 225
# Sucesso para 34
# Processado 34 de 225
# Sucesso para 35
# Processado 35 de 225
# Sucesso para 36
# Processado 36 de 225
# Sucesso para 37
# Processado 37 de 225
# Sucesso para 39
# Processado 39 de 225
# Sucesso para 40
# Processado 40 de 225
# Sucesso para 42
# Processado 42 de 225
# Sucesso para 43
# Processado 43 de 225
# Sucesso para 45
# Processado 45 de 225
# Sucesso para 46
# Processado 46 de 225
# Sucesso para 47
# Processado 47 de 225
# Sucesso para 48
# Processado 48 de 225
# Sucesso para 49
# Processado 49 de 225
# Sucesso para 50
# Processado 50 de 225
# Sucesso para 51
# Processado 51 de 225
# Sucesso para 52
# Processado 52 de 225
# Sucesso para 53
# Processado 53 de 225
# Sucesso para 54
# Processado 54 de 225
# Sucesso para 55
# Processado 55 de 225
# Sucesso para 56
# Processado 56 de 225
# Erro 429: Muitas requisições. Aguardando 10 segundos antes de tentar novamente...
# Sucesso para 57
# Processado 57 de 225
# Sucesso para 58
# Processado 58 de 225
# Erro 429: Muitas requisições. Aguardando 10 segundos antes de tentar novamente...
# Sucesso para 59
# Processado 59 de 225
# Sucesso para 60
# Processado 60 de 225
# Erro 429: Muitas requisições. Aguardando 10 segundos antes de tentar novamente...
# Sucesso para 61
# Processado 61 de 225
# Sucesso para 62
# Processado 62 de 225
# Erro 429: Muitas requisições. Aguardando 10 segundos antes de tentar novamente...
# Sucesso para 63
# Processado 63 de 225
# Sucesso para 64
# Processado 64 de 225
# Erro 429: Muitas requisições. Aguardando 10 segundos antes de tentar novamente...
# Sucesso para 65
# Processado 65 de 225
# Sucesso para 66
# Processado 66 de 225
# Sucesso para 67
# Processado 67 de 225
# Sucesso para 68
# Processado 68 de 225
# Sucesso para 69
# Processado 69 de 225
# Sucesso para 70
# Processado 70 de 225
# Sucesso para 71
# Processado 71 de 225
# Sucesso para 72
# Processado 72 de 225
# Sucesso para 73
# Processado 73 de 225
# Sucesso para 74
# Processado 74 de 225
# Sucesso para 75
# Processado 75 de 225
# Sucesso para 76
# Processado 76 de 225
# Sucesso para 77
# Processado 77 de 225
# Sucesso para 78
# Processado 78 de 225
# Sucesso para 79
# Processado 79 de 225
# Sucesso para 80
# Processado 80 de 225
# Sucesso para 81
# Processado 81 de 225
# Sucesso para 82
# Processado 82 de 225
# Sucesso para 83
# Processado 83 de 225
# Sucesso para 84
# Processado 84 de 225
# Sucesso para 85
# Processado 85 de 225
# Sucesso para 86
# Processado 86 de 225
# Sucesso para 87
# Processado 87 de 225
# Sucesso para 88
# Processado 88 de 225
# Sucesso para 89
# Processado 89 de 225
# Sucesso para 90
# Processado 90 de 225
# Sucesso para 91
# Processado 91 de 225
# Sucesso para 92
# Processado 92 de 225
# Sucesso para 93
# Processado 93 de 225
# Sucesso para 94
# Processado 94 de 225
# Sucesso para 95
# Processado 95 de 225
# Sucesso para 96
# Processado 96 de 225
# Sucesso para 97
# Processado 97 de 225
# Sucesso para 98
# Processado 98 de 225
# Sucesso para 99
# Processado 99 de 225
# Sucesso para 100
# Processado 100 de 225
# Sucesso para 101
# Processado 101 de 225
# Sucesso para 102
# Processado 102 de 225
# Sucesso para 103
# Processado 103 de 225
# Sucesso para 104
# Processado 104 de 225
# Sucesso para 105
# Processado 105 de 225
# Sucesso para 106
# Processado 106 de 225
# Sucesso para 107
# Processado 107 de 225
# Sucesso para 108
# Processado 108 de 225
# Sucesso para 109
# Processado 109 de 225
# Sucesso para 110
# Processado 110 de 225
# Sucesso para 111
# Processado 111 de 225
# Sucesso para 112
# Processado 112 de 225
# Sucesso para 114
# Processado 114 de 225
# Sucesso para 115
# Processado 115 de 225
# Sucesso para 116
# Processado 116 de 225
# Sucesso para 117
# Processado 117 de 225
# Sucesso para 118
# Processado 118 de 225
# Sucesso para 119
# Processado 119 de 225
# Sucesso para 120
# Processado 120 de 225
# Sucesso para 121
# Processado 121 de 225
# Sucesso para 122
# Processado 122 de 225
# Sucesso para 123
# Processado 123 de 225
# Sucesso para 124
# Processado 124 de 225
# Sucesso para 125
# Processado 125 de 225
# Sucesso para 126
# Processado 126 de 225
# Sucesso para 127
# Processado 127 de 225
# Sucesso para 128
# Processado 128 de 225
# Sucesso para 129
# Processado 129 de 225
# Sucesso para 131
# Processado 131 de 225
# Sucesso para 132
# Processado 132 de 225
# Sucesso para 133
# Processado 133 de 225
# Sucesso para 134
# Processado 134 de 225
# Sucesso para 135
# Processado 135 de 225
# Sucesso para 136
# Processado 136 de 225
# Sucesso para 137
# Processado 137 de 225
# Sucesso para 138
# Processado 138 de 225
# Sucesso para 139
# Processado 139 de 225
# Sucesso para 140
# Processado 140 de 225
# Sucesso para 141
# Processado 141 de 225
# Sucesso para 142
# Processado 142 de 225
# Sucesso para 143
# Processado 143 de 225
# Sucesso para 144
# Processado 144 de 225
# Sucesso para 145
# Processado 145 de 225
# Sucesso para 146
# Processado 146 de 225
# Sucesso para 147
# Processado 147 de 225
# Sucesso para 148
# Processado 148 de 225
# Sucesso para 150
# Processado 150 de 225
# Sucesso para 151
# Processado 151 de 225
# Sucesso para 152
# Processado 152 de 225
# Sucesso para 153
# Processado 153 de 225
# Sucesso para 154
# Processado 154 de 225
# Sucesso para 155
# Processado 155 de 225
# Sucesso para 156
# Processado 156 de 225
# Sucesso para 157
# Processado 157 de 225
# Sucesso para 158
# Processado 158 de 225
# Sucesso para 159
# Processado 159 de 225
# Sucesso para 160
# Processado 160 de 225
# Sucesso para 161
# Processado 161 de 225
# Sucesso para 162
# Processado 162 de 225
# Sucesso para 163
# Processado 163 de 225
# Sucesso para 164
# Processado 164 de 225
# Sucesso para 165
# Processado 165 de 225
# Sucesso para 166
# Processado 166 de 225
# Sucesso para 167
# Processado 167 de 225
# Sucesso para 168
# Processado 168 de 225
# Sucesso para 169
# Processado 169 de 225
# Sucesso para 170
# Processado 170 de 225
# Sucesso para 171
# Processado 171 de 225
# Sucesso para 172
# Processado 172 de 225
# Sucesso para 173
# Processado 173 de 225
# Sucesso para 174
# Processado 174 de 225
# Sucesso para 175
# Processado 175 de 225
# Sucesso para 176
# Processado 176 de 225
# Sucesso para 177
# Processado 177 de 225
# Sucesso para 178
# Processado 178 de 225
# Sucesso para 179
# Processado 179 de 225
# Sucesso para 180
# Processado 180 de 225
# Sucesso para 181
# Processado 181 de 225
# Sucesso para 182
# Processado 182 de 225
# Sucesso para 183
# Processado 183 de 225
# Sucesso para 184
# Processado 184 de 225
# Sucesso para 186
# Processado 186 de 225
# Sucesso para 187
# Processado 187 de 225
# Sucesso para 188
# Processado 188 de 225
# Sucesso para 189
# Processado 189 de 225
# Sucesso para 190
# Processado 190 de 225
# Sucesso para 191
# Processado 191 de 225
# Sucesso para 192
# Processado 192 de 225
# Sucesso para 193
# Processado 193 de 225
# Sucesso para 194
# Processado 194 de 225
# Sucesso para 195
# Processado 195 de 225
# Sucesso para 196
# Processado 196 de 225
# Sucesso para 197
# Processado 197 de 225
# Sucesso para 198
# Processado 198 de 225
# Sucesso para 199
# Processado 199 de 225
# Sucesso para 200
# Processado 200 de 225
# Sucesso para 201
# Processado 201 de 225
# Sucesso para 202
# Processado 202 de 225
# Sucesso para 203
# Processado 203 de 225
# Sucesso para 204
# Processado 204 de 225
# Sucesso para 205
# Processado 205 de 225
# Sucesso para 206
# Processado 206 de 225
# Sucesso para 207
# Processado 207 de 225
# Sucesso para 208
# Processado 208 de 225
# Sucesso para 209
# Processado 209 de 225
# Sucesso para 210
# Processado 210 de 225
# Sucesso para 211
# Processado 211 de 225
# Sucesso para 212
# Processado 212 de 225
# Sucesso para 213
# Processado 213 de 225
# Sucesso para 214
# Processado 214 de 225
# Sucesso para 215
# Processado 215 de 225
# Sucesso para 216
# Processado 216 de 225
# Sucesso para 217
# Processado 217 de 225
# Sucesso para 218
# Processado 218 de 225
# Sucesso para 219
# Processado 219 de 225
# Sucesso para 220
# Processado 220 de 225
# Sucesso para 221
# Processado 221 de 225
# Sucesso para 222
# Processado 222 de 225
# Sucesso para 223
# Processado 223 de 225
# Sucesso para 224
# Processado 224 de 225
# Sucesso para 225
# Processado 225 de 225
# Sucesso para 226
# Processado 226 de 225
# Sucesso para 227
# Processado 227 de 225
# Sucesso para 228
# Processado 228 de 225
# Sucesso para 229
# Processado 229 de 225
# Sucesso para 230
# Processado 230 de 225
# Sucesso para 231
# Processado 231 de 225
# Sucesso para 232
# Processado 232 de 225
# Sucesso para 233
# Processado 233 de 225

# %%
df_final.to_excel('df_final.xlsx')

# %%
import time
payload = {"dealStatusText": "lost"}  # Atualizando para "lost"
BASE_URL = "https://api.agendor.com.br/v3"

i = 0
for deal_id in bad_deals_id[88:]:
    url = f"{BASE_URL}/deals/{deal_id}/status"
    wait_time = 10  # Tempo de espera inicial

    while True:
        response = requests.put(url, headers=headers, json=payload)

        if response.status_code == 200:
            wait_time = 10  # Reseta o tempo de espera se der certo
            print(f"Sucesso para {i}")  # Corrigido o uso de f-string
            break
            
        elif response.status_code == 429:
            print(f"Erro 429: Muitas requisições. Aguardando {wait_time} segundos antes de tentar novamente...")
            time.sleep(wait_time)
            wait_time *= 2  # Dobra o tempo de espera a cada falha
        else:
            print(f"Erro inesperado para {i}: {response.status_code}")
            break  # Você pode optar por parar ou continuar com outro comportamento

    i += 1
    print(f"Processado {i} de {len(bad_deals_id)}")
# Out:
# {'data': [{'id': 27531374,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55328371,
#     'name': 'Israel Elihom Da Silva Pereira',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270603,
#     'name': '4.2 ACOMPANHAR POSTAGEM',
#     'sequence': 2,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Israel Elihom Da Silva Pereira',
#    'description': None,
#    'startTime': '2024-11-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-07T21:38:33.000Z',
#    'updatedAt': '2025-03-13T17:20:00.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'israel-698720n27531374@to.agendor.com.br',
#    'customFields': {'tpv_historico': '24.6',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30520, 'value': 'Inside'},
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27531374'},
#   {'id': 27536292,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55575732, 'name': 'Helio Augusto Ferreira', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270603,
#     'name': '4.2 ACOMPANHAR POSTAGEM',
#     'sequence': 2,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#    'title': 'Helio Augusto Ferreira',
#    'description': None,
#    'startTime': '2024-11-08T00:00:00.000Z',
#    'endTime': '2025-03-07T18:50:31.000Z',
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-08T04:59:50.000Z',
#    'updatedAt': '2025-03-13T16:34:47.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'helio-698720n27536292@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27536292'},
#   {'id': 31584274,
#    'parentDealId': 31553227,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58199329,
#     'name': 'CÍCERO SOUSA ARAÚJO FILHO',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 3, 'name': 'Perdido'},
#    'lossReason': {'id': 2898660, 'name': 'Não se aplica', 'description': None},
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9525 - 9520 - 9519 - 9518 - CÍCERO SOUSA ARAÚJO FILHO',
#    'description': None,
#    'startTime': '2025-03-13T00:00:00.000Z',
#    'endTime': '2025-03-13T00:00:00.000Z',
#    'wonAt': None,
#    'lostAt': '2025-03-13T14:50:48.000Z',
#    'createdAt': '2025-03-13T14:45:56.000Z',
#    'updatedAt': '2025-03-13T14:50:48.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9525-698720n31584274@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31584274'},
#   {'id': 31553227,
#    'parentDealId': 31553221,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58199329,
#     'name': 'CÍCERO SOUSA ARAÚJO FILHO',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186649,
#     'name': '3.1 NOVOS ATIVOS',
#     'sequence': 1,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 3, 'name': 'Perdido'},
#    'lossReason': {'id': 2898660,
#     'name': 'Não se aplica',
#     'description': 'Duplicado.'},
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9520 - 9519 - 9518 - CÍCERO SOUSA ARAÚJO FILHO',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': '2025-03-13T00:00:00.000Z',
#    'wonAt': None,
#    'lostAt': '2025-03-13T14:45:57.000Z',
#    'createdAt': '2025-03-12T15:03:58.000Z',
#    'updatedAt': '2025-03-13T14:45:57.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9520-698720n31553227@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31553227'},
#   {'id': 29634886,
#    'parentDealId': 29597079,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57659559,
#     'name': 'DAYANE FERREIRA RODRIGUES VIANA',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186650,
#     'name': '3.3 RISCO DE CHURN',
#     'sequence': 3,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'title': '9169 - DAYANE FERREIRA RODRIGUES VIANA',
#    'description': 'Carnaval',
#    'startTime': '2025-02-14T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-02-14T20:45:39.000Z',
#    'updatedAt': '2025-03-13T13:43:27.000Z',
#    'ranking': 0,
#    'value': 337.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9169-698720n29634886@to.agendor.com.br',
#    'customFields': {'tpv_historico': '337.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30519, 'value': 'Field'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': '0.0',
#     'adquirente': [{'id': 33068, 'value': 'Inter'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29634886'},
#   {'id': 27531423,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55574653, 'name': 'Salete de oliveira', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186650,
#     'name': '3.3 RISCO DE CHURN',
#     'sequence': 3,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Salete De Oliveira',
#    'description': None,
#    'startTime': '2024-11-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-07T21:38:34.000Z',
#    'updatedAt': '2025-03-13T13:42:32.000Z',
#    'ranking': 0,
#    'value': 6355.2,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'salete-698720n27531423@to.agendor.com.br',
#    'customFields': {'tpv_historico': '77830.89',
#     'tpv_mes_anterior': '46909.69',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30520, 'value': 'Inside'},
#     'tpv_m-2': '24566.0',
#     'adquirente': [{'id': 33067, 'value': 'OWN'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27531423'},
#   {'id': 31577780,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58457096, 'name': 'Rosa Marisa', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Rosa Marisa',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-13T12:44:29.000Z',
#    'updatedAt': '2025-03-13T13:36:04.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'rosa-698720n31577780@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31577780'},
#   {'id': 31577905,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58459934, 'name': 'Luiz', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Luiz',
#    'description': None,
#    'startTime': '2025-03-13T12:48:13.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-13T12:48:13.000Z',
#    'updatedAt': '2025-03-13T12:48:27.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'luiz-698720n31577905@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31577905'},
#   {'id': 31577874,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58456195, 'name': 'Beni', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Beni',
#    'description': None,
#    'startTime': '2025-03-13T12:47:17.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-13T12:47:17.000Z',
#    'updatedAt': '2025-03-13T12:47:41.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'beni-698720n31577874@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31577874'},
#   {'id': 31565047,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58453506, 'name': 'Maria Das Gracas', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Maria Das Gracas',
#    'description': None,
#    'startTime': '2025-03-12T20:07:36.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T20:07:36.000Z',
#    'updatedAt': '2025-03-12T20:09:12.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'maria-698720n31565047@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'},
#      {'id': 36728, 'value': 'Criativo'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None,
#     'reprovacao_saque': [{'id': 37060, 'value': 'Empréstimo'},
#      {'id': 37058, 'value': 'Sem Cartão'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31565047'},
#   {'id': 31553221,
#    'parentDealId': 31553144,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58199329,
#     'name': 'CÍCERO SOUSA ARAÚJO FILHO',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186645,
#     'name': '2.1 VINCULAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 773196, 'name': '2 SERVICE'}},
#    'dealStatus': {'id': 2, 'name': 'Ganho'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9519 - 9518 - CÍCERO SOUSA ARAÚJO FILHO',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': '2025-03-12T00:00:00.000Z',
#    'wonAt': '2025-03-12T15:03:59.000Z',
#    'lostAt': None,
#    'createdAt': '2025-03-12T15:03:50.000Z',
#    'updatedAt': '2025-03-12T15:03:59.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9519-698720n31553221@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31553221'},
#   {'id': 31553144,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58199329,
#     'name': 'CÍCERO SOUSA ARAÚJO FILHO',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'dealStage': {'id': 3182353,
#     'name': '1.1 LEADS',
#     'sequence': 1,
#     'funnel': {'id': 772312, 'name': '1 POS'}},
#    'dealStatus': {'id': 2, 'name': 'Ganho'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9518 - CÍCERO SOUSA ARAÚJO FILHO',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': '2025-03-12T00:00:00.000Z',
#    'wonAt': '2025-03-12T15:03:51.000Z',
#    'lostAt': None,
#    'createdAt': '2025-03-12T15:01:19.000Z',
#    'updatedAt': '2025-03-12T15:03:51.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9518-698720n31553144@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31553144'},
#   {'id': 29843694,
#    'parentDealId': 28700223,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55579660,
#     'name': 'Francisco Jose Da Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186649,
#     'name': '3.1 NOVOS ATIVOS',
#     'sequence': 1,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'title': '9412 - 8716 - Francisco José da Silva',
#    'description': None,
#    'startTime': '2025-02-25T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-02-25T14:24:33.000Z',
#    'updatedAt': '2025-03-12T14:59:52.000Z',
#    'ranking': 0,
#    'value': 1000.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9412-698720n29843694@to.agendor.com.br',
#    'customFields': {'tpv_historico': '1000.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30519, 'value': 'Field'},
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'tpv_m-2': '0.0',
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29843694'},
#   {'id': 29843727,
#    'parentDealId': 28681521,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55579660,
#     'name': 'Francisco Jose Da Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186649,
#     'name': '3.1 NOVOS ATIVOS',
#     'sequence': 1,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 3, 'name': 'Perdido'},
#    'lossReason': {'id': 2898660,
#     'name': 'Não se aplica',
#     'description': 'Duplicado'},
#    'owner': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'title': '9413 - Francisco José da Silva',
#    'description': None,
#    'startTime': '2025-02-25T00:00:00.000Z',
#    'endTime': '2025-03-12T00:00:00.000Z',
#    'wonAt': None,
#    'lostAt': '2025-03-12T14:59:30.000Z',
#    'createdAt': '2025-02-25T14:25:08.000Z',
#    'updatedAt': '2025-03-12T14:59:30.000Z',
#    'ranking': 0,
#    'value': 1000.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9413-698720n29843727@to.agendor.com.br',
#    'customFields': {'tpv_historico': '1000.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30519, 'value': 'Field'},
#     'tpv_m-2': '0.0',
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29843727'},
#   {'id': 31553095,
#    'parentDealId': 29843727,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55579660,
#     'name': 'Francisco Jose Da Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'title': '9517 - 9413 - Francisco José da Silva',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:59:29.000Z',
#    'updatedAt': '2025-03-12T14:59:29.000Z',
#    'ranking': 0,
#    'value': 1000.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9517-698720n31553095@to.agendor.com.br',
#    'customFields': {'tpv_historico': '1000.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30519, 'value': 'Field'},
#     'tpv_m-2': '0.0',
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31553095'},
#   {'id': 31552869,
#    'parentDealId': 31552865,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58446352,
#     'name': 'Victor Emannuel Medeiros Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186645,
#     'name': '2.1 VINCULAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 773196, 'name': '2 SERVICE'}},
#    'dealStatus': {'id': 2, 'name': 'Ganho'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9515 - Victor Emannuel Medeiros Silva',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': '2025-03-12T00:00:00.000Z',
#    'wonAt': '2025-03-12T14:55:17.000Z',
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:54:50.000Z',
#    'updatedAt': '2025-03-12T14:55:17.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9515-698720n31552869@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31552869'},
#   {'id': 31552882,
#    'parentDealId': 31552869,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58446352,
#     'name': 'Victor Emannuel Medeiros Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3186649,
#     'name': '3.1 NOVOS ATIVOS',
#     'sequence': 1,
#     'funnel': {'id': 773197, 'name': '3 CUSTOMER SUCCESS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': '9516 - 9515 - Victor Emannuel Medeiros Silva',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:55:16.000Z',
#    'updatedAt': '2025-03-12T14:55:16.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9516-698720n31552882@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31552882'},
#   {'id': 31552865,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58446352,
#     'name': 'Victor Emannuel Medeiros Silva',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'dealStage': {'id': 3182353,
#     'name': '1.1 LEADS',
#     'sequence': 1,
#     'funnel': {'id': 772312, 'name': '1 POS'}},
#    'dealStatus': {'id': 2, 'name': 'Ganho'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': 'Victor Emannuel Medeiros Silva',
#    'description': None,
#    'startTime': '2025-03-12T00:00:00.000Z',
#    'endTime': '2025-03-12T00:00:00.000Z',
#    'wonAt': '2025-03-12T14:54:52.000Z',
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:54:46.000Z',
#    'updatedAt': '2025-03-12T14:54:52.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'victor-698720n31552865@to.agendor.com.br',
#    'customFields': {'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31552865'},
#   {'id': 31552838,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58446344,
#     'name': '                          Joana Darque',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Joana Darque',
#    'description': None,
#    'startTime': '2025-03-12T14:54:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:54:00.000Z',
#    'updatedAt': '2025-03-12T14:54:00.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'joana-698720n31552838@to.agendor.com.br',
#    'customFields': {},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31552838'},
#   {'id': 31552025,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58445837, 'name': 'Luiz Alberto Lucena', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Luiz Alberto Lucena',
#    'description': None,
#    'startTime': '2025-03-11T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:32:58.000Z',
#    'updatedAt': '2025-03-12T14:33:43.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'luiz-698720n31552025@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31552025'},
#   {'id': 31551561,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58439121, 'name': 'Rosalina Cardoso', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Rosalina Cardoso.',
#    'description': None,
#    'startTime': '2025-03-11T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:22:19.000Z',
#    'updatedAt': '2025-03-12T14:27:19.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'rosalina-698720n31551561@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'},
#      {'id': 36728, 'value': 'Criativo'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31551561'},
#   {'id': 31551506,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58445562,
#     'name': '       Gilmarsinturion Gonzalez                   ',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Gilmarsinturion Gonzalez',
#    'description': None,
#    'startTime': '2025-03-11T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T14:21:23.000Z',
#    'updatedAt': '2025-03-12T14:21:40.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'gilmarsinturion-698720n31551506@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36797, 'value': 'LP'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31551506'},
#   {'id': 31548248,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58192998, 'name': 'Maria Madalena', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3226395,
#     'name': '5.1 CONTATO WHATSAPP',
#     'sequence': 1,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Maria Madalena.',
#    'description': None,
#    'startTime': '2025-03-11T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-12T13:03:52.000Z',
#    'updatedAt': '2025-03-12T13:04:12.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'maria-698720n31548248@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36728, 'value': 'Criativo'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31548248'},
#   {'id': 28824971,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57130836, 'name': 'Shirley,alex E Kauan', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3318983,
#     'name': '5.6 REMARKETING',
#     'sequence': 6,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Shirley',
#    'description': None,
#    'startTime': '2025-01-13T18:43:24.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-01-13T18:43:24.000Z',
#    'updatedAt': '2025-03-11T17:56:56.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'shirley-698720n28824971@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None,
#     'reprovacao_saque': [{'id': 37063,
#       'value': 'Desistência por falta de contato'}]},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=28824971'},
#   {'id': 28979383,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57258236, 'name': 'Fabiani Santos', 'email': None},
#    'author': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'dealStage': {'id': 3318983,
#     'name': '5.6 REMARKETING',
#     'sequence': 6,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Fabiani Santos',
#    'description': None,
#    'startTime': '2025-01-21T12:32:59.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-01-21T12:32:59.000Z',
#    'updatedAt': '2025-03-11T17:56:38.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
# ...
#   {'id': 29435494,
#    'parentDealId': 29240404,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57476165, 'name': 'Igor Santana Oliveira', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': '9108 - 9015 - Igor Santana Oliveira',
#    'description': 'CAMPANHA',
#    'startTime': '2025-02-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-02-07T12:45:18.000Z',
#    'updatedAt': '2025-03-10T20:31:30.000Z',
#    'ranking': 0,
#    'value': 78.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9108-698720n29435494@to.agendor.com.br',
#    'customFields': {'tpv_historico': '78.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}],
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29435494'},
#   {'id': 29619807,
#    'parentDealId': 29276678,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57520613,
#     'name': 'Jose Milton da Conceição',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': '9164 - 9040 - JOSÉ MILTON DA CONCEIÇÃO',
#    'description': 'CARNAVAL',
#    'startTime': '2025-02-14T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-02-14T17:30:01.000Z',
#    'updatedAt': '2025-03-10T20:31:12.000Z',
#    'ranking': 0,
#    'value': 68.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9164-698720n29619807@to.agendor.com.br',
#    'customFields': {'tpv_historico': '68.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}],
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29619807'},
#   {'id': 29501848,
#    'parentDealId': 29193314,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 57473302, 'name': 'Aline franco dionizio', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': '9126 - 8984 - Aline franco dionizio',
#    'description': 'Carnaval',
#    'startTime': '2025-02-10T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-02-10T20:37:58.000Z',
#    'updatedAt': '2025-03-10T20:30:54.000Z',
#    'ranking': 0,
#    'value': 450.8,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '9126-698720n29501848@to.agendor.com.br',
#    'customFields': {'tpv_historico': '450.8',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 36299, 'value': 'Camp. Carnaval'},
#     'campanha': [{'id': 33759, 'value': 'Carnaval'}],
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=29501848'},
#   {'id': 28389902,
#    'parentDealId': 28339511,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 56605765,
#     'name': 'Eduardo Lucas Deodato 1',
#     'email': 'eduardolucasdeodato@gmail.com'},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'title': '8484 - 8472 - Eduardo Deodato-Dr. Hotdog',
#    'description': None,
#    'startTime': '2024-12-12T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-12-12T12:56:11.000Z',
#    'updatedAt': '2025-03-10T19:47:49.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': '8484-698720n28389902@to.agendor.com.br',
#    'customFields': {'tpv_historico': '888.11',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30519, 'value': 'Field'},
#     'tpv_m-2': '888.11',
#     'adquirente': [{'id': 33068, 'value': 'Inter'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=28389902'},
#   {'id': 31490536,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 58387223, 'name': 'Angélica', 'email': None},
#    'author': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'dealStage': {'id': 3186634,
#     'name': '5.2 LINK CADASTRO',
#     'sequence': 2,
#     'funnel': {'id': 773194, 'name': '5 SAQUE DIGITAL'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#    'title': 'Angélica',
#    'description': None,
#    'startTime': '2025-03-09T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2025-03-10T16:20:39.000Z',
#    'updatedAt': '2025-03-10T19:31:51.000Z',
#    'ranking': 0,
#    'value': 0.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'angelica-698720n31490536@to.agendor.com.br',
#    'customFields': {'tpv_historico': None,
#     'tpv_mes_anterior': None,
#     'tpv_acordado': None,
#     'canal_de_venda': None,
#     'campanha': [{'id': 36729, 'value': 'Site'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None,
#     'tpv_m-2': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=31490536'},
#   {'id': 27531390,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55328387,
#     'name': 'Luiz Carlos Borja De Almeida Junior',
#     'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Luiz Carlos Borja De Almeida Junior',
#    'description': None,
#    'startTime': '2024-11-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-07T21:38:34.000Z',
#    'updatedAt': '2025-03-10T18:47:18.000Z',
#    'ranking': 0,
#    'value': 1.01,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'luiz-698720n27531390@to.agendor.com.br',
#    'customFields': {'tpv_historico': '1.01',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30520, 'value': 'Inside'},
#     'adquirente': [{'id': 33067, 'value': 'OWN'}],
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27531390'},
#   {'id': 27531452,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55328449, 'name': 'Jean Guilherme Marçal', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Jean Guilherme Marçal',
#    'description': None,
#    'startTime': '2024-11-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-07T21:38:35.000Z',
#    'updatedAt': '2025-03-10T18:47:15.000Z',
#    'ranking': 0,
#    'value': 2.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'jean-698720n27531452@to.agendor.com.br',
#    'customFields': {'tpv_historico': '3.5',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30520, 'value': 'Inside'},
#     'adquirente': [{'id': 33067, 'value': 'OWN'}],
#     'tpv_m-2': '0.0'},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27531452'},
#   {'id': 27531405,
#    'parentDealId': None,
#    'accountId': 698720,
#    'organization': None,
#    'person': {'id': 55328402, 'name': 'Lucas Figueira Eliseu', 'email': None},
#    'author': {'accountId': 698720, 'id': 860639, 'name': 'Guilherme Hely'},
#    'dealStage': {'id': 3270602,
#     'name': '4.1 COMUNICAÇÃO',
#     'sequence': 1,
#     'funnel': {'id': 791207, 'name': '4 RECOLHIMENTO DE POS'}},
#    'dealStatus': {'id': 1, 'name': 'Em andamento'},
#    'lossReason': None,
#    'owner': {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#    'title': 'Lucas Figueira Eliseu',
#    'description': None,
#    'startTime': '2024-11-07T00:00:00.000Z',
#    'endTime': None,
#    'wonAt': None,
#    'lostAt': None,
#    'createdAt': '2024-11-07T21:38:34.000Z',
#    'updatedAt': '2025-03-10T18:46:03.000Z',
#    'ranking': 0,
#    'value': 2.0,
#    'products': [],
#    'allowedUsers': [{'accountId': 698720,
#      'id': 860639,
#      'name': 'Guilherme Hely'},
#     {'accountId': 698720, 'id': 860979, 'name': 'Camila Neves'},
#     {'accountId': 698720, 'id': 860980, 'name': 'Gustavo Porto'},
#     {'accountId': 698720, 'id': 863021, 'name': 'Juliane Sales'},
#     {'accountId': 698720, 'id': 864760, 'name': 'Sandro Leao'},
#     {'accountId': 698720, 'id': 864772, 'name': 'Rhay Amorim'},
#     {'accountId': 698720, 'id': 867560, 'name': 'João Marcelo'},
#     {'accountId': 698720, 'id': 867562, 'name': 'Leandro Miranda'},
#     {'accountId': 698720, 'id': 881078, 'name': 'Vitor Carvalho'},
#     {'accountId': 698720, 'id': 885372, 'name': 'Ferramentas'}],
#    '_email': 'lucas-698720n27531405@to.agendor.com.br',
#    'customFields': {'tpv_historico': '9.0',
#     'tpv_mes_anterior': '0.0',
#     'tpv_acordado': None,
#     'canal_de_venda': {'id': 30520, 'value': 'Inside'},
#     'tpv_m-2': '0.0',
#     'adquirente': [{'id': 33067, 'value': 'OWN'}],
#     'data_de_envio_da_pos': None,
#     'data_de_recebimento_da_pos': None},
#    '_webUrl': 'https://web.agendor.com.br/sistema/negocios/historico.php?id=27531405'}],
#  'meta': {'totalCount': 7663},
#  'links': {'self': 'https://api.agendor.com.br/v3/deals?per_page=100&withCustomFields=True',
#   'next': 'https://api.agendor.com.br/v3/deals?page=2&per_page=100&withCustomFields=True'}}

# %%
214241.4
